# %% [markdown]
# # ChromaDB hacking
# Broken - dimensions issue

# %%
import os

# %%
! pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.4.24-py3-none-any.whl.metadata (7.3 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: requests>=2.28 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from chromadb) (2.7.0)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Downloading chroma_hnswlib-0.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.110.1-py3-none-any.whl.metadata (24 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.29.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.22.5 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from chromadb) (4.10.0)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Downloading pulsar_client-3.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.24.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.45b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.24.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from chromadb) (0.15.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from chromadb) (4.66.2)
# Requirement already satisfied: overrides>=7.3.1 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from chromadb) (1.59.3)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-4.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting orjson>=3.9.12 (from chromadb)
#   Downloading orjson-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=19.1 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (24.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: certifi>=14.05.14 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.29.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.2.1)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (4.24.4)
# Requirement already satisfied: sympy in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<=7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-7.0.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-proto==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-asgi==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.45b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.45b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-util-http==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.45b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: setuptools>=16.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (69.2.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: monotonic>=1.5 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (2.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from requests>=2.28->chromadb) (3.6)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb) (0.22.2)
# Requirement already satisfied: click>=8.0.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer>=0.9.0->chromadb)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: h11>=0.8 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-12.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.2.0)
# Requirement already satisfied: zipp>=0.5 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer>=0.9.0->chromadb)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.17.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (4.3.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath>=0.19 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.3.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/sean/mambaforge/envs/nvidia-test/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.1)
# Downloading chromadb-0.4.24-py3-none-any.whl (525 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 5.2 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading chroma_hnswlib-0.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 13.2 MB/s eta 0:00:00m eta 0:00:010:01
# Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl (698 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 18.1 MB/s eta 0:00:00m eta 0:00:01
# Downloading build-1.2.1-py3-none-any.whl (21 kB)
# Downloading fastapi-0.110.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 10.2 MB/s eta 0:00:00
# Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.9 MB/s eta 0:00:0031m22.2 MB/s eta 0:00:01
# Downloading mmh3-4.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 16.7 MB/s eta 0:00:00
# Downloading onnxruntime-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 15.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading opentelemetry_api-1.24.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 15.6 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.24.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 13.5 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.45b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation-0.45b0-py3-none-any.whl (28 kB)
# Downloading opentelemetry_instrumentation_asgi-0.45b0-py3-none-any.whl (14 kB)
# Downloading opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl (36 kB)
# Downloading opentelemetry_util_http-0.45b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.24.0-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 19.1 MB/s eta 0:00:00
# Downloading orjson-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 20.3 MB/s eta 0:00:00
# Downloading pulsar_client-3.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 14.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 7.0 MB/s eta 0:00:00
# Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 15.3 MB/s eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.1/229.1 kB 18.9 MB/s eta 0:00:00
# Downloading httptools-0.6.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.5/318.5 kB 20.4 MB/s eta 0:00:00
# Downloading importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 19.6 MB/s eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 11.5 MB/s eta 0:00:00
# Downloading uvloop-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 14.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading watchfiles-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.0 MB/s eta 0:00:000m eta 0:00:010:01:01
# Downloading websockets-12.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.9/130.9 kB 34.2 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 11.4 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.7 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 15.9 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53724 sha256=3e965096130bd770a285c155d88bcd7a338ceb743b2d71fadb5bdd172ca80d28
#   Stored in directory: /home/sean/.cache/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, mmh3, websockets, uvloop, uvicorn, shellingham, python-dotenv, pyproject_hooks, pulsar-client, orjson, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, mdurl, importlib-metadata, humanfriendly, httptools, googleapis-common-protos, deprecated, chroma-hnswlib, bcrypt, asgiref, watchfiles, starlette, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, markdown-it-py, coloredlogs, build, rich, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, kubernetes, fastapi, typer, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 7.1.0
#     Uninstalling importlib_metadata-7.1.0:
#       Successfully uninstalled importlib_metadata-7.1.0
# Successfully installed asgiref-3.8.1 bcrypt-4.1.2 build-1.2.1 chroma-hnswlib-0.7.3 chromadb-0.4.24 coloredlogs-15.0.1 deprecated-1.2.14 fastapi-0.110.1 googleapis-common-protos-1.63.0 httptools-0.6.1 humanfriendly-10.0 importlib-metadata-7.0.0 kubernetes-29.0.0 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-4.1.0 onnxruntime-1.17.1 opentelemetry-api-1.24.0 opentelemetry-exporter-otlp-proto-common-1.24.0 opentelemetry-exporter-otlp-proto-grpc-1.24.0 opentelemetry-instrumentation-0.45b0 opentelemetry-instrumentation-asgi-0.45b0 opentelemetry-instrumentation-fastapi-0.45b0 opentelemetry-proto-1.24.0 opentelemetry-sdk-1.24.0 opentelemetry-semantic-conventions-0.45b0 opentelemetry-util-http-0.45b0 orjson-3.10.0 pulsar-client-3.4.0 pypika-0.48.9 pyproject_hooks-1.0.0 python-dotenv-1.0.1 rich-13.7.1 shellingham-1.5.4 starlette-0.37.2 typer-0.12.3 uvicorn-0.29.0 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0

# %%
import chromadb
chroma_client = chromadb.Client()

# %%
# from chromadb.errors import InvalidDimensionException

# try:
#     docsearch = Chroma.from_documents(documents=..., embedding=...)
# except InvalidDimensionException:
#     Chroma().delete_collection()
#     docsearch = Chroma.from_documents(documents=..., embedding=...)

# %%
collection = chroma_client.create_collection(name="cdb-hacking", )

# %%
collection.add(
    documents=["This is a document", "This is another document"],
    metadatas=[{"source": "my_source"}, {"source": "my_source"}],
    ids=["id1", "id2"]
)

# %%
collection.add(
    embeddings=[[1.2, 2.3, 4.5], [6.7, 8.2, 9.2]],
    documents=["This is a document", "This is another document"],
#     metadatas=[{"source": "my_source"}, {"source": "my_source"}],
    ids=["id1", "id2"]
)
# Out:
# ---------------------------------------------------------------------------
# InvalidDimensionException                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 collection.add(
#       2     embeddings=[[1.2, 2.3, 4.5], [6.7, 8.2, 9.2]],
#       3     documents=["This is a document", "This is another document"],
#       4 #     metadatas=[{"source": "my_source"}, {"source": "my_source"}],
#       5     ids=["id1", "id2"]
#       6 )
#
# File ~/mambaforge/envs/nvidia-test/lib/python3.11/site-packages/chromadb/api/models/Collection.py:168, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#     163             raise ValueError(
#     164                 "You must set a data loader on the collection if loading from URIs."
#     165             )
#     166         embeddings = self._embed(self._data_loader(uris))
# --> 168 self._client._add(ids, self.id, embeddings, metadatas, documents, uris)
#
# File ~/mambaforge/envs/nvidia-test/lib/python3.11/site-packages/chromadb/telemetry/opentelemetry/__init__.py:127, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     125 global tracer, granularity
#     126 if trace_granularity < granularity:
# --> 127     return f(*args, **kwargs)
#     128 if not tracer:
#     129     return f(*args, **kwargs)
#
# File ~/mambaforge/envs/nvidia-test/lib/python3.11/site-packages/chromadb/api/segment.py:377, in SegmentAPI._add(self, ids, collection_id, embeddings, metadatas, documents, uris)
#     367 records_to_submit = []
#     368 for r in _records(
#     369     t.Operation.ADD,
#     370     ids=ids,
#    (...)
#     375     uris=uris,
#     376 ):
# --> 377     self._validate_embedding_record(coll, r)
#     378     records_to_submit.append(r)
#     379 self._producer.submit_embeddings(coll["topic"], records_to_submit)
#
# File ~/mambaforge/envs/nvidia-test/lib/python3.11/site-packages/chromadb/telemetry/opentelemetry/__init__.py:127, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     125 global tracer, granularity
#     126 if trace_granularity < granularity:
# --> 127     return f(*args, **kwargs)
#     128 if not tracer:
#     129     return f(*args, **kwargs)
#
# File ~/mambaforge/envs/nvidia-test/lib/python3.11/site-packages/chromadb/api/segment.py:803, in SegmentAPI._validate_embedding_record(self, collection, record)
#     801 add_attributes_to_current_span({"collection_id": str(collection["id"])})
#     802 if record["embedding"]:
# --> 803     self._validate_dimension(collection, len(record["embedding"]), update=True)
#
# File ~/mambaforge/envs/nvidia-test/lib/python3.11/site-packages/chromadb/telemetry/opentelemetry/__init__.py:127, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     125 global tracer, granularity
#     126 if trace_granularity < granularity:
# --> 127     return f(*args, **kwargs)
#     128 if not tracer:
#     129     return f(*args, **kwargs)
#
# File ~/mambaforge/envs/nvidia-test/lib/python3.11/site-packages/chromadb/api/segment.py:818, in SegmentAPI._validate_dimension(self, collection, dim, update)
#     816         self._collection_cache[id]["dimension"] = dim
#     817 elif collection["dimension"] != dim:
# --> 818     raise InvalidDimensionException(
#     819         f"Embedding dimension {dim} does not match collection dimensionality {collection['dimension']}"
#     820     )
#     821 else:
#     822     return
#
# InvalidDimensionException: Embedding dimension 3 does not match collection dimensionality 384
