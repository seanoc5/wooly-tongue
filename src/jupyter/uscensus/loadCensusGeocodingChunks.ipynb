# %% [markdown]
# # Load cached results of US Census batch geocoding

# %%
import pandas as pd
import io
from sqlalchemy import create_engine, Table, Column, Integer, String, MetaData, PrimaryKeyConstraint

# %%
import glob

path = '/opt/data/GIS-Census/florida/geocoding'
files = glob.glob(f"{path}/*.csv")

# Define column names
column_names = ['voterid', 'address_in', 'match_indicator', 'match_type', 'address_out', 'long_lat', 'tiger_edge', 'street_side', 'fips_state', 'fips_county', 'census_tract', 'census_block']

# Define the data types for each column
column_types = {
    'voterid': 'int64',
    'address_in': 'str',
    'match_indicator': 'str',
    'match_type': 'str',
    'address_out': 'str',
    'long_lat': 'str',
    'tiger_edge': 'str',
    'street_side': 'str',
    'fips_state': 'str',
    'fips_county': 'str',
    'census_tract': 'str',
    'census_block': 'str'
}

# chatgpt suggestion/alternative
# Define the metadata and table with primary key constraint
# metadata = MetaData()
# table = Table(
#     'geolocations', metadata,
#     Column('voterid', Integer, primary_key=True),  # This is the index column from the DataFrame
#     Column('match_indicator', String),
#     Column('match_type', String),
#     Column('address_in', String),
#     Column('address_out', String),
#     Column('long_lat', String),
#     Column('tiger_edge', String),
#     Column('street_side', String),
#     Column('fips_state', String),
#     Column('fips_county', String),
#     Column('census_tract', String),
#     Column('census_block', String),
    # PrimaryKeyConstraint('id')  # Define the primary key constraint
# )

# %%
df_geocoded = []
for f in files:
    csv = pd.read_csv(f, header=None, on_bad_lines='warn', low_memory=False, index_col=None, dtype=column_types, names=column_names,)
    df_matches = csv[csv['address_out'].isna() == False]
    print(f"File: {f} csv:({len(csv)}) -- matches:({len(df_matches)})")
    df_geocoded.append(df_matches)
    
# combine all the little df's together...    
df_geocoded = pd.concat(df_geocoded)
df_geocoded
# Out:
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-69000.csv csv:(1000) -- matches:(951)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-233000.csv csv:(1000) -- matches:(965)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_7.csv csv:(5000) -- matches:(3640)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-6000.csv csv:(1000) -- matches:(976)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-309000.csv csv:(1000) -- matches:(965)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-241000.csv csv:(1000) -- matches:(969)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-445000.csv csv:(1000) -- matches:(533)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-264000.csv csv:(1000) -- matches:(961)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-203000.csv csv:(1000) -- matches:(981)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-245000.csv csv:(1000) -- matches:(962)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_16.csv csv:(5000) -- matches:(2201)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-355000.csv csv:(1000) -- matches:(966)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-410000.csv csv:(1000) -- matches:(978)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_12.csv csv:(5000) -- matches:(754)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-577000.csv csv:(1000) -- matches:(963)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-10000.csv csv:(1000) -- matches:(853)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-189000.csv csv:(1000) -- matches:(961)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-202000.csv csv:(1000) -- matches:(976)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-394000.csv csv:(1000) -- matches:(991)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-397000.csv csv:(1000) -- matches:(977)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-596000.csv csv:(1000) -- matches:(931)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-492000.csv csv:(1000) -- matches:(924)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-522000.csv csv:(1000) -- matches:(919)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-2000.csv csv:(2000) -- matches:(978)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-363000.csv csv:(1000) -- matches:(925)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-1000.csv csv:(1000) -- matches:(973)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-67000.csv csv:(1000) -- matches:(927)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-356000.csv csv:(1000) -- matches:(908)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-392000.csv csv:(1000) -- matches:(982)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-151000.csv csv:(1000) -- matches:(901)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-186000.csv csv:(1000) -- matches:(918)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-611000.csv csv:(1000) -- matches:(979)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-374000.csv csv:(1000) -- matches:(976)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-348000.csv csv:(1000) -- matches:(894)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-471000.csv csv:(1000) -- matches:(934)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-80000.csv csv:(1000) -- matches:(952)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-373000.csv csv:(1000) -- matches:(977)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-179000.csv csv:(1000) -- matches:(950)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-278000.csv csv:(1000) -- matches:(979)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-280000.csv csv:(1000) -- matches:(985)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-616000.csv csv:(1000) -- matches:(943)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-198000.csv csv:(1000) -- matches:(968)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-489000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-375000.csv csv:(1000) -- matches:(986)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-461000.csv csv:(1000) -- matches:(921)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-293000.csv csv:(1000) -- matches:(972)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-51000.csv csv:(1000) -- matches:(939)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-246000.csv csv:(1000) -- matches:(964)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-176000.csv csv:(1000) -- matches:(943)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-423000.csv csv:(1000) -- matches:(979)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-104000.csv csv:(1000) -- matches:(965)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-508000.csv csv:(1000) -- matches:(910)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-223000.csv csv:(1000) -- matches:(933)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-172000.csv csv:(1000) -- matches:(973)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-414000.csv csv:(1000) -- matches:(972)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-554000.csv csv:(1000) -- matches:(906)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-552000.csv csv:(1000) -- matches:(952)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-72000.csv csv:(1000) -- matches:(964)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-582000.csv csv:(1000) -- matches:(953)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-127000.csv csv:(1000) -- matches:(850)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-193000.csv csv:(1000) -- matches:(987)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-516000.csv csv:(1000) -- matches:(951)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-353000.csv csv:(1000) -- matches:(946)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-454000.csv csv:(1000) -- matches:(772)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-256000.csv csv:(1000) -- matches:(957)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-622000.csv csv:(1000) -- matches:(887)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-265000.csv csv:(1000) -- matches:(931)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-194000.csv csv:(1000) -- matches:(967)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-117000.csv csv:(1000) -- matches:(895)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-24000.csv csv:(1000) -- matches:(964)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-405000.csv csv:(1000) -- matches:(974)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-459000.csv csv:(1000) -- matches:(920)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-396000.csv csv:(1000) -- matches:(989)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-188000.csv csv:(1000) -- matches:(982)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-93000.csv csv:(1000) -- matches:(914)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-134000.csv csv:(1000) -- matches:(868)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-212000.csv csv:(1000) -- matches:(932)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-453000.csv csv:(1000) -- matches:(347)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-371000.csv csv:(1000) -- matches:(983)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-573000.csv csv:(1000) -- matches:(967)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-118000.csv csv:(1000) -- matches:(934)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-317000.csv csv:(1000) -- matches:(828)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-250000.csv csv:(1000) -- matches:(974)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-379000.csv csv:(1000) -- matches:(986)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-81000.csv csv:(1000) -- matches:(951)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-47000.csv csv:(1000) -- matches:(942)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-62000.csv csv:(1000) -- matches:(842)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_9.csv csv:(5000) -- matches:(2159)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-330000.csv csv:(1000) -- matches:(977)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-54000.csv csv:(1000) -- matches:(930)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-593000.csv csv:(1000) -- matches:(955)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-61000.csv csv:(1000) -- matches:(890)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-175000.csv csv:(1000) -- matches:(971)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-556000.csv csv:(1000) -- matches:(921)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-36000.csv csv:(1000) -- matches:(973)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-305000.csv csv:(1000) -- matches:(973)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-530000.csv csv:(1000) -- matches:(781)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-243000.csv csv:(1000) -- matches:(983)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-34000.csv csv:(1000) -- matches:(967)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-119000.csv csv:(1000) -- matches:(961)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-435000.csv csv:(1000) -- matches:(991)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-215000.csv csv:(1000) -- matches:(941)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-48000.csv csv:(1000) -- matches:(945)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-283000.csv csv:(1000) -- matches:(984)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-145000.csv csv:(1000) -- matches:(974)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-313000.csv csv:(1000) -- matches:(988)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-164000.csv csv:(1000) -- matches:(895)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-548000.csv csv:(1000) -- matches:(939)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-608000.csv csv:(1000) -- matches:(895)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-34000.csv csv:(2000) -- matches:(752)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-451000.csv csv:(1000) -- matches:(17)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-568000.csv csv:(1000) -- matches:(895)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-184000.csv csv:(1000) -- matches:(976)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-346000.csv csv:(1000) -- matches:(901)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-320000.csv csv:(1000) -- matches:(842)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-126000.csv csv:(1000) -- matches:(944)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-583000.csv csv:(1000) -- matches:(960)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-463000.csv csv:(1000) -- matches:(909)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-4000.csv csv:(2000) -- matches:(959)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-467000.csv csv:(1000) -- matches:(820)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_4.csv csv:(5000) -- matches:(3014)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-575000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-32000.csv csv:(2000) -- matches:(893)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-133000.csv csv:(1000) -- matches:(946)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-372000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-361000.csv csv:(1000) -- matches:(968)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-43000.csv csv:(1000) -- matches:(856)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-350000.csv csv:(1000) -- matches:(878)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-425000.csv csv:(1000) -- matches:(956)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-383000.csv csv:(1000) -- matches:(914)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-404000.csv csv:(1000) -- matches:(979)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-110000.csv csv:(1000) -- matches:(969)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-214000.csv csv:(1000) -- matches:(978)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-159000.csv csv:(1000) -- matches:(821)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-115000.csv csv:(1000) -- matches:(969)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-314000.csv csv:(1000) -- matches:(953)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-378000.csv csv:(1000) -- matches:(969)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-413000.csv csv:(1000) -- matches:(980)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-349000.csv csv:(1000) -- matches:(899)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-393000.csv csv:(1000) -- matches:(986)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-142000.csv csv:(1000) -- matches:(971)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-287000.csv csv:(1000) -- matches:(977)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-402000.csv csv:(1000) -- matches:(973)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-440000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-433000.csv csv:(1000) -- matches:(966)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-318000.csv csv:(1000) -- matches:(799)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-540000.csv csv:(1000) -- matches:(912)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-199000.csv csv:(1000) -- matches:(966)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-106000.csv csv:(1000) -- matches:(967)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-479000.csv csv:(1000) -- matches:(978)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-619000.csv csv:(1000) -- matches:(943)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-495000.csv csv:(1000) -- matches:(949)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-279000.csv csv:(1000) -- matches:(982)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-281000.csv csv:(1000) -- matches:(983)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-438000.csv csv:(1000) -- matches:(973)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-228000.csv csv:(1000) -- matches:(951)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-598000.csv csv:(1000) -- matches:(915)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-120000.csv csv:(1000) -- matches:(924)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-403000.csv csv:(1000) -- matches:(971)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-347000.csv csv:(1000) -- matches:(902)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-254000.csv csv:(1000) -- matches:(969)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-316000.csv csv:(1000) -- matches:(812)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-139000.csv csv:(1000) -- matches:(940)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-244000.csv csv:(1000) -- matches:(968)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-138000.csv csv:(1000) -- matches:(974)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-206000.csv csv:(1000) -- matches:(957)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-20000.csv csv:(1000) -- matches:(954)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-108000.csv csv:(1000) -- matches:(950)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-253000.csv csv:(1000) -- matches:(976)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-201000.csv csv:(1000) -- matches:(978)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-294000.csv csv:(1000) -- matches:(979)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-277000.csv csv:(1000) -- matches:(981)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-141000.csv csv:(1000) -- matches:(961)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-232000.csv csv:(1000) -- matches:(963)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-42000.csv csv:(1000) -- matches:(795)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-12000.csv csv:(2000) -- matches:(953)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-562000.csv csv:(1000) -- matches:(888)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-533000.csv csv:(1000) -- matches:(791)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-437000.csv csv:(1000) -- matches:(967)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-248000.csv csv:(1000) -- matches:(960)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-367000.csv csv:(1000) -- matches:(918)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-240000.csv csv:(1000) -- matches:(970)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-298000.csv csv:(1000) -- matches:(929)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-183000.csv csv:(1000) -- matches:(972)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-472000.csv csv:(1000) -- matches:(908)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-329000.csv csv:(1000) -- matches:(986)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-341000.csv csv:(1000) -- matches:(753)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-594000.csv csv:(1000) -- matches:(956)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-417000.csv csv:(1000) -- matches:(977)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-557000.csv csv:(1000) -- matches:(906)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-534000.csv csv:(1000) -- matches:(830)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-74000.csv csv:(1000) -- matches:(963)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-539000.csv csv:(1000) -- matches:(891)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-337000.csv csv:(1000) -- matches:(955)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-143000.csv csv:(1000) -- matches:(979)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-150000.csv csv:(1000) -- matches:(923)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-296000.csv csv:(1000) -- matches:(940)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-149000.csv csv:(1000) -- matches:(903)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-628000.csv csv:(1000) -- matches:(966)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-427000.csv csv:(1000) -- matches:(991)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-618000.csv csv:(1000) -- matches:(926)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-114000.csv csv:(1000) -- matches:(968)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-274000.csv csv:(1000) -- matches:(972)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-33000.csv csv:(1000) -- matches:(964)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-338000.csv csv:(1000) -- matches:(959)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-331000.csv csv:(1000) -- matches:(973)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-0.csv csv:(2000) -- matches:(739)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-251000.csv csv:(1000) -- matches:(956)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-632000.csv csv:(536) -- matches:(514)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-66000.csv csv:(1000) -- matches:(931)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-476000.csv csv:(1000) -- matches:(923)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-386000.csv csv:(1000) -- matches:(967)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-22000.csv csv:(2000) -- matches:(924)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-521000.csv csv:(1000) -- matches:(934)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-292000.csv csv:(1000) -- matches:(947)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-267000.csv csv:(1000) -- matches:(934)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-535000.csv csv:(1000) -- matches:(905)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-399000.csv csv:(1000) -- matches:(941)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-218000.csv csv:(1000) -- matches:(933)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-528000.csv csv:(1000) -- matches:(824)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-443000.csv csv:(1000) -- matches:(851)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-591000.csv csv:(1000) -- matches:(958)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-136000.csv csv:(1000) -- matches:(616)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-592000.csv csv:(1000) -- matches:(950)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-295000.csv csv:(1000) -- matches:(979)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-527000.csv csv:(1000) -- matches:(922)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_15.csv csv:(5000) -- matches:(3621)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-398000.csv csv:(1000) -- matches:(984)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-239000.csv csv:(1000) -- matches:(966)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-2000.csv csv:(1000) -- matches:(974)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-9000.csv csv:(1000) -- matches:(850)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-255000.csv csv:(1000) -- matches:(956)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-56000.csv csv:(1000) -- matches:(931)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-354000.csv csv:(1000) -- matches:(971)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-524000.csv csv:(1000) -- matches:(771)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-617000.csv csv:(1000) -- matches:(923)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_13.csv csv:(5000) -- matches:(3139)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-380000.csv csv:(1000) -- matches:(968)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-242000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-57000.csv csv:(1000) -- matches:(950)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-590000.csv csv:(1000) -- matches:(955)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-204000.csv csv:(1000) -- matches:(972)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-620000.csv csv:(1000) -- matches:(882)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-137000.csv csv:(1000) -- matches:(743)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-315000.csv csv:(1000) -- matches:(833)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-607000.csv csv:(1000) -- matches:(880)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-85000.csv csv:(1000) -- matches:(944)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-311000.csv csv:(1000) -- matches:(984)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-125000.csv csv:(1000) -- matches:(737)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-630000.csv csv:(1000) -- matches:(957)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-88000.csv csv:(1000) -- matches:(933)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-208000.csv csv:(1000) -- matches:(948)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-457000.csv csv:(1000) -- matches:(890)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-310000.csv csv:(1000) -- matches:(981)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-488000.csv csv:(1000) -- matches:(980)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-45000.csv csv:(1000) -- matches:(951)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-480000.csv csv:(1000) -- matches:(963)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-15000.csv csv:(1000) -- matches:(958)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-409000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-123000.csv csv:(1000) -- matches:(801)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-565000.csv csv:(1000) -- matches:(971)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-168000.csv csv:(1000) -- matches:(984)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-18000.csv csv:(2000) -- matches:(773)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-17000.csv csv:(1000) -- matches:(948)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-26000.csv csv:(1000) -- matches:(969)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-300000.csv csv:(1000) -- matches:(919)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-362000.csv csv:(1000) -- matches:(939)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-339000.csv csv:(1000) -- matches:(705)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-455000.csv csv:(1000) -- matches:(789)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-519000.csv csv:(1000) -- matches:(888)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-75000.csv csv:(1000) -- matches:(912)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-185000.csv csv:(1000) -- matches:(980)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-357000.csv csv:(1000) -- matches:(904)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-167000.csv csv:(1000) -- matches:(919)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-502000.csv csv:(1000) -- matches:(980)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-19000.csv csv:(1000) -- matches:(938)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-370000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-260000.csv csv:(1000) -- matches:(950)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-49000.csv csv:(1000) -- matches:(968)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-46000.csv csv:(1000) -- matches:(938)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-491000.csv csv:(1000) -- matches:(924)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-59000.csv csv:(1000) -- matches:(940)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-364000.csv csv:(1000) -- matches:(955)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-26000.csv csv:(2000) -- matches:(927)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-301000.csv csv:(1000) -- matches:(910)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-422000.csv csv:(1000) -- matches:(979)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-432000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-460000.csv csv:(1000) -- matches:(928)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-32000.csv csv:(1000) -- matches:(973)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-411000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-178000.csv csv:(1000) -- matches:(962)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-322000.csv csv:(1000) -- matches:(756)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-490000.csv csv:(1000) -- matches:(928)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-71000.csv csv:(1000) -- matches:(954)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-529000.csv csv:(1000) -- matches:(792)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-532000.csv csv:(1000) -- matches:(796)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-190000.csv csv:(1000) -- matches:(978)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-513000.csv csv:(1000) -- matches:(959)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-581000.csv csv:(1000) -- matches:(964)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-99000.csv csv:(1000) -- matches:(974)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-224000.csv csv:(1000) -- matches:(916)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-428000.csv csv:(1000) -- matches:(993)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-132000.csv csv:(1000) -- matches:(937)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-430000.csv csv:(1000) -- matches:(986)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-187000.csv csv:(1000) -- matches:(968)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_20.csv csv:(3249) -- matches:(2515)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-226000.csv csv:(1000) -- matches:(937)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-25000.csv csv:(1000) -- matches:(970)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-129000.csv csv:(1000) -- matches:(808)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-627000.csv csv:(1000) -- matches:(958)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-416000.csv csv:(1000) -- matches:(971)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-50000.csv csv:(1000) -- matches:(939)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-205000.csv csv:(1000) -- matches:(986)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-249000.csv csv:(1000) -- matches:(957)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-332000.csv csv:(1000) -- matches:(972)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-130000.csv csv:(1000) -- matches:(842)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-154000.csv csv:(1000) -- matches:(937)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_10.csv csv:(5000) -- matches:(3811)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-324000.csv csv:(1000) -- matches:(957)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-302000.csv csv:(1000) -- matches:(913)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-368000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-0.csv csv:(1000) -- matches:(983)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-574000.csv csv:(1000) -- matches:(962)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-16000.csv csv:(1000) -- matches:(939)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-92000.csv csv:(1000) -- matches:(910)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-96000.csv csv:(1000) -- matches:(922)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-197000.csv csv:(1000) -- matches:(983)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-559000.csv csv:(1000) -- matches:(950)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-22000.csv csv:(1000) -- matches:(949)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-181000.csv csv:(1000) -- matches:(958)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-98000.csv csv:(1000) -- matches:(929)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-625000.csv csv:(1000) -- matches:(963)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-450000.csv csv:(1000) -- matches:(492)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-335000.csv csv:(1000) -- matches:(942)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-124000.csv csv:(1000) -- matches:(779)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-507000.csv csv:(1000) -- matches:(956)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-35000.csv csv:(1000) -- matches:(964)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-588000.csv csv:(1000) -- matches:(953)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-76000.csv csv:(1000) -- matches:(890)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-78000.csv csv:(1000) -- matches:(933)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-499000.csv csv:(1000) -- matches:(750)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-31000.csv csv:(1000) -- matches:(974)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-571000.csv csv:(1000) -- matches:(897)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-496000.csv csv:(1000) -- matches:(927)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-77000.csv csv:(1000) -- matches:(905)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-247000.csv csv:(1000) -- matches:(970)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-169000.csv csv:(1000) -- matches:(979)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-503000.csv csv:(1000) -- matches:(970)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-131000.csv csv:(1000) -- matches:(928)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-420000.csv csv:(1000) -- matches:(968)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-389000.csv csv:(1000) -- matches:(981)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-229000.csv csv:(1000) -- matches:(966)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_1.csv csv:(5000) -- matches:(2652)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-442000.csv csv:(1000) -- matches:(952)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-585000.csv csv:(1000) -- matches:(958)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-121000.csv csv:(1000) -- matches:(943)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-152000.csv csv:(1000) -- matches:(911)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-434000.csv csv:(1000) -- matches:(987)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-291000.csv csv:(1000) -- matches:(934)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-21000.csv csv:(1000) -- matches:(953)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-604000.csv csv:(1000) -- matches:(625)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-16000.csv csv:(2000) -- matches:(878)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-441000.csv csv:(1000) -- matches:(950)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-497000.csv csv:(1000) -- matches:(837)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-135000.csv csv:(1000) -- matches:(596)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-448000.csv csv:(1000) -- matches:(485)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-526000.csv csv:(1000) -- matches:(583)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-257000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-415000.csv csv:(1000) -- matches:(971)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-486000.csv csv:(1000) -- matches:(738)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-599000.csv csv:(1000) -- matches:(912)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-268000.csv csv:(1000) -- matches:(936)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-493000.csv csv:(1000) -- matches:(943)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-586000.csv csv:(1000) -- matches:(964)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-544000.csv csv:(1000) -- matches:(939)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-83000.csv csv:(1000) -- matches:(938)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-343000.csv csv:(1000) -- matches:(836)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-509000.csv csv:(1000) -- matches:(918)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-55000.csv csv:(1000) -- matches:(934)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-90000.csv csv:(1000) -- matches:(961)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-478000.csv csv:(1000) -- matches:(915)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_6.csv csv:(5000) -- matches:(4048)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-13000.csv csv:(1000) -- matches:(859)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-456000.csv csv:(1000) -- matches:(762)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-360000.csv csv:(1000) -- matches:(980)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-358000.csv csv:(1000) -- matches:(912)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-94000.csv csv:(1000) -- matches:(921)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-288000.csv csv:(1000) -- matches:(954)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-538000.csv csv:(1000) -- matches:(894)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-289000.csv csv:(1000) -- matches:(955)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-211000.csv csv:(1000) -- matches:(936)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-100000.csv csv:(1000) -- matches:(952)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-65000.csv csv:(1000) -- matches:(937)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-597000.csv csv:(1000) -- matches:(910)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-326000.csv csv:(1000) -- matches:(959)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-351000.csv csv:(1000) -- matches:(890)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-572000.csv csv:(1000) -- matches:(912)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-395000.csv csv:(1000) -- matches:(986)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-276000.csv csv:(1000) -- matches:(969)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-400000.csv csv:(1000) -- matches:(951)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-474000.csv csv:(1000) -- matches:(906)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-498000.csv csv:(1000) -- matches:(832)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-252000.csv csv:(1000) -- matches:(968)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-325000.csv csv:(1000) -- matches:(947)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-609000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-553000.csv csv:(1000) -- matches:(909)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-615000.csv csv:(1000) -- matches:(941)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-270000.csv csv:(1000) -- matches:(910)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-11000.csv csv:(1000) -- matches:(876)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-421000.csv csv:(1000) -- matches:(987)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-116000.csv csv:(1000) -- matches:(954)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-144000.csv csv:(1000) -- matches:(978)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-369000.csv csv:(1000) -- matches:(979)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-261000.csv csv:(1000) -- matches:(925)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-191000.csv csv:(1000) -- matches:(974)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-600000.csv csv:(1000) -- matches:(881)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-286000.csv csv:(1000) -- matches:(964)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-345000.csv csv:(1000) -- matches:(909)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-589000.csv csv:(1000) -- matches:(961)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-501000.csv csv:(1000) -- matches:(976)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-334000.csv csv:(1000) -- matches:(951)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-107000.csv csv:(1000) -- matches:(948)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-629000.csv csv:(1000) -- matches:(966)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-40000.csv csv:(1000) -- matches:(797)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-523000.csv csv:(1000) -- matches:(868)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-30000.csv csv:(1000) -- matches:(984)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-29000.csv csv:(1000) -- matches:(950)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-473000.csv csv:(1000) -- matches:(916)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-487000.csv csv:(1000) -- matches:(822)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-505000.csv csv:(1000) -- matches:(981)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-160000.csv csv:(1000) -- matches:(812)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-536000.csv csv:(1000) -- matches:(915)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-5000.csv csv:(1000) -- matches:(987)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-10000.csv csv:(2000) -- matches:(835)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-8000.csv csv:(2000) -- matches:(857)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-165000.csv csv:(1000) -- matches:(878)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-541000.csv csv:(1000) -- matches:(910)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-494000.csv csv:(1000) -- matches:(913)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-24000.csv csv:(2000) -- matches:(991)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-570000.csv csv:(1000) -- matches:(873)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-304000.csv csv:(1000) -- matches:(942)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-424000.csv csv:(1000) -- matches:(957)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-60000.csv csv:(1000) -- matches:(949)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-258000.csv csv:(1000) -- matches:(965)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-483000.csv csv:(1000) -- matches:(803)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-587000.csv csv:(1000) -- matches:(952)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_19.csv csv:(5000) -- matches:(3028)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-227000.csv csv:(1000) -- matches:(962)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-547000.csv csv:(1000) -- matches:(918)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_17.csv csv:(5000) -- matches:(3743)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-561000.csv csv:(1000) -- matches:(842)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-84000.csv csv:(1000) -- matches:(936)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-484000.csv csv:(1000) -- matches:(756)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-537000.csv csv:(1000) -- matches:(931)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-412000.csv csv:(1000) -- matches:(973)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-158000.csv csv:(1000) -- matches:(840)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-28000.csv csv:(2000) -- matches:(893)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_14.csv csv:(5000) -- matches:(2906)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-30000.csv csv:(2000) -- matches:(963)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-222000.csv csv:(1000) -- matches:(957)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-376000.csv csv:(1000) -- matches:(976)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-558000.csv csv:(1000) -- matches:(925)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-70000.csv csv:(1000) -- matches:(966)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-140000.csv csv:(1000) -- matches:(938)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-506000.csv csv:(1000) -- matches:(982)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-37000.csv csv:(1000) -- matches:(961)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-147000.csv csv:(1000) -- matches:(982)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-381000.csv csv:(1000) -- matches:(962)
# ...
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-447000.csv csv:(1000) -- matches:(479)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-225000.csv csv:(1000) -- matches:(928)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_18.csv csv:(5000) -- matches:(4115)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-312000.csv csv:(1000) -- matches:(980)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-436000.csv csv:(1000) -- matches:(991)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-612000.csv csv:(1000) -- matches:(982)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-284000.csv csv:(1000) -- matches:(953)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-52000.csv csv:(1000) -- matches:(932)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-631000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-626000.csv csv:(1000) -- matches:(953)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-38000.csv csv:(1000) -- matches:(982)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-510000.csv csv:(1000) -- matches:(899)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-468000.csv csv:(1000) -- matches:(821)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-44000.csv csv:(1000) -- matches:(225)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-614000.csv csv:(1000) -- matches:(968)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-408000.csv csv:(1000) -- matches:(976)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-3000.csv csv:(1000) -- matches:(974)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-282000.csv csv:(1000) -- matches:(990)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-105000.csv csv:(1000) -- matches:(966)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-220000.csv csv:(1000) -- matches:(951)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-321000.csv csv:(1000) -- matches:(794)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-285000.csv csv:(1000) -- matches:(922)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-195000.csv csv:(1000) -- matches:(971)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-192000.csv csv:(1000) -- matches:(978)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-391000.csv csv:(1000) -- matches:(976)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-377000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-14000.csv csv:(1433) -- matches:(691)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-231000.csv csv:(1000) -- matches:(967)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-446000.csv csv:(1000) -- matches:(502)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-387000.csv csv:(1000) -- matches:(962)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-4000.csv csv:(1000) -- matches:(982)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-419000.csv csv:(1000) -- matches:(956)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-259000.csv csv:(1000) -- matches:(982)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_11.csv csv:(5000) -- matches:(3237)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-342000.csv csv:(1000) -- matches:(746)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-153000.csv csv:(1000) -- matches:(946)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-429000.csv csv:(1000) -- matches:(992)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-595000.csv csv:(1000) -- matches:(953)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-384000.csv csv:(1000) -- matches:(901)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-112000.csv csv:(1000) -- matches:(961)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-14000.csv csv:(1000) -- matches:(953)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-319000.csv csv:(1000) -- matches:(803)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-263000.csv csv:(1000) -- matches:(965)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-407000.csv csv:(1000) -- matches:(967)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-216000.csv csv:(1000) -- matches:(924)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-303000.csv csv:(1000) -- matches:(918)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-234000.csv csv:(1000) -- matches:(967)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-213000.csv csv:(1000) -- matches:(949)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-584000.csv csv:(1000) -- matches:(956)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-514000.csv csv:(1000) -- matches:(975)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-209000.csv csv:(1000) -- matches:(945)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-307000.csv csv:(1000) -- matches:(963)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-517000.csv csv:(1000) -- matches:(921)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-182000.csv csv:(1000) -- matches:(947)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-89000.csv csv:(1000) -- matches:(934)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-109000.csv csv:(1000) -- matches:(962)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-470000.csv csv:(1000) -- matches:(831)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-352000.csv csv:(1000) -- matches:(897)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-481000.csv csv:(1000) -- matches:(860)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-207000.csv csv:(1000) -- matches:(932)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-157000.csv csv:(1000) -- matches:(912)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-162000.csv csv:(1000) -- matches:(847)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-27000.csv csv:(1000) -- matches:(966)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-273000.csv csv:(1000) -- matches:(834)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-39000.csv csv:(1000) -- matches:(874)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-462000.csv csv:(1000) -- matches:(928)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-601000.csv csv:(1000) -- matches:(646)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-344000.csv csv:(1000) -- matches:(771)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-8000.csv csv:(1000) -- matches:(899)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-382000.csv csv:(1000) -- matches:(924)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-388000.csv csv:(1000) -- matches:(967)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-452000.csv csv:(1000) -- matches:(0)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-275000.csv csv:(1000) -- matches:(972)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-297000.csv csv:(1000) -- matches:(928)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-102000.csv csv:(1000) -- matches:(957)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-546000.csv csv:(1000) -- matches:(756)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-262000.csv csv:(1000) -- matches:(949)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-180000.csv csv:(1000) -- matches:(946)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-418000.csv csv:(1000) -- matches:(974)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-465000.csv csv:(1000) -- matches:(781)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-171000.csv csv:(1000) -- matches:(968)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-340000.csv csv:(1000) -- matches:(735)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-466000.csv csv:(1000) -- matches:(811)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-475000.csv csv:(1000) -- matches:(921)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-359000.csv csv:(1000) -- matches:(904)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-272000.csv csv:(1000) -- matches:(791)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-385000.csv csv:(1000) -- matches:(948)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-511000.csv csv:(1000) -- matches:(923)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-605000.csv csv:(1000) -- matches:(701)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-87000.csv csv:(1000) -- matches:(956)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-163000.csv csv:(1000) -- matches:(843)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-91000.csv csv:(1000) -- matches:(966)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-53000.csv csv:(1000) -- matches:(958)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-18000.csv csv:(1000) -- matches:(948)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-566000.csv csv:(1000) -- matches:(950)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-217000.csv csv:(1000) -- matches:(926)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-177000.csv csv:(1000) -- matches:(955)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-606000.csv csv:(1000) -- matches:(878)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-449000.csv csv:(1000) -- matches:(493)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-333000.csv csv:(1000) -- matches:(987)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-113000.csv csv:(1000) -- matches:(974)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-365000.csv csv:(1000) -- matches:(924)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-613000.csv csv:(1000) -- matches:(974)
# File: /opt/data/GIS-Census/florida/geocoding/unmatched_responses-20000.csv csv:(2000) -- matches:(827)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-580000.csv csv:(1000) -- matches:(933)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-200000.csv csv:(1000) -- matches:(980)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-101000.csv csv:(1000) -- matches:(953)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-73000.csv csv:(1000) -- matches:(957)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-306000.csv csv:(1000) -- matches:(969)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-41000.csv csv:(1000) -- matches:(792)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-86000.csv csv:(1000) -- matches:(927)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-545000.csv csv:(1000) -- matches:(897)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-560000.csv csv:(1000) -- matches:(961)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-238000.csv csv:(1000) -- matches:(972)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-308000.csv csv:(1000) -- matches:(972)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-431000.csv csv:(1000) -- matches:(977)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-550000.csv csv:(1000) -- matches:(934)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-520000.csv csv:(1000) -- matches:(938)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-623000.csv csv:(1000) -- matches:(877)
# File: /opt/data/GIS-Census/florida/geocoding/data_result_8.csv csv:(5000) -- matches:(3287)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-237000.csv csv:(1000) -- matches:(952)
# File: /opt/data/GIS-Census/florida/geocoding/district_responses-79000.csv csv:(1000) -- matches:(924)
#        voterid                                         address_in  \
# 0    103817568  12566 Mission Hills Cir S, Jacksonville, FL, 3...
# 1    132459240       1548 Oak Ridge Dr W, Jacksonville, FL, 32225
# 2    116077807      11643 Dunes Way Dr N, Jacksonville, FL, 32225
# 3    103529009    12547 Masters Ridge Dr, Jacksonville, FL, 32225
# 4    130864686    12496 Masters Ridge Dr, Jacksonville, FL, 32225
# ..         ...                                                ...
# 994  103504015       14135 Ivylgail Dr N, Jacksonville, FL, 32225
# 996  103750897   13783 Quartz Crystal Dr, Jacksonville, FL, 32225
# 997  118368272   2759 McCormick Woods Dr, Jacksonville, FL, 32225
# 998  103516226     14064 Broken Bow Dr S, Jacksonville, FL, 32225
# 999  103457683         1421 Sun Marsh Dr, Jacksonville, FL, 32225
#
#     match_indicator match_type  \
# 0             Match      Exact
# 1             Match      Exact
# 2             Match      Exact
# 3             Match      Exact
# 4             Match      Exact
# ..              ...        ...
# 994           Match      Exact
# 996           Match      Exact
# 997           Match      Exact
# 998           Match      Exact
# 999           Match      Exact
#
#                                            address_out  \
# 0    12566 MISSION HILLS CIR S, JACKSONVILLE, FL, 3...
# 1         1548 OAK RIDGE DR W, JACKSONVILLE, FL, 32225
# 2        11643 DUNES WAY DR N, JACKSONVILLE, FL, 32225
# 3      12547 MASTERS RIDGE DR, JACKSONVILLE, FL, 32225
# 4      12496 MASTERS RIDGE DR, JACKSONVILLE, FL, 32225
# ..                                                 ...
# 994       14135 IVYLGAIL DR N, JACKSONVILLE, FL, 32225
# 996   13783 QUARTZ CRYSTAL DR, JACKSONVILLE, FL, 32225
# 997   2759 MCCORMICK WOODS DR, JACKSONVILLE, FL, 32225
# 998     14064 BROKEN BOW DR S, JACKSONVILLE, FL, 32225
# 999         1421 SUN MARSH DR, JACKSONVILLE, FL, 32225
#
#                                   long_lat tiger_edge street_side fips_state  \
# 0      -81.4959208485605,30.37552925684173   83941007           L         12
# 1     -81.5175612592775,30.347330152139023   83936709           L         12
# 2    -81.50784565362517,30.360735718988167  640433643           R         12
# 3    -81.49696020758995,30.372375202129547   83986461           L         12
# 4     -81.49796247944619,30.37238874038468   83986461           R         12
# ..                                     ...        ...         ...        ...
# 994   -81.47185563759984,30.36685643354997   83906113           L         12
# 996  -81.48136082294849,30.358010796389294   83980602           L         12
# 997   -81.48335930815978,30.36120952365991   83941000           R         12
# 998  -81.47444713016063,30.355822053000622   83980944           R         12
# 999   -81.4682015941305,30.348904115531525   83958112           L         12
#
#     fips_county census_tract census_block
# 0           031       014334         2001
# 1           031       014328         2003
# 2           031       014333         1005
# 3           031       014334         2001
# 4           031       014334         2001
# ..          ...          ...          ...
# 994         031       014330         1008
# 996         031       014335         2004
# 997         031       014334         2009
# 998         031       014335         2000
# 999         031       014335         4012
#
# [654778 rows x 12 columns]

# %%
df_geocoded['geocoder'] = 'US Census'
df_geocoded['placeid'] = ''
df_geocoded['geoid'] = df_geocoded['fips_state'] +df_geocoded['fips_county'] + df_geocoded['census_tract'] + df_geocoded['census_block']
# Geocoding file count:(670) --> record count:(654778)      -- was:(761218 with non-matches)
print(f"Geocoding file count:({len(files)}) --> record count:({len(df_geocoded)})")
# Out:
# Geocoding file count:(670) --> record count:(654778)

# %%
# matched: 654778, unmatched: 106440
df_geo = df_geocoded[df_geocoded['address_out'].isna() == False]
print(f"matched:({len(df_geo)})")
# Out:
# matched:(654778)

# %%
# duplicates(?): 222635 (full), 105175 (matched only)
# keep=first
df_geo.sort_values(by='voterid', inplace=True)
df_dups = df_geo[df_geo.duplicated(subset=['voterid'], keep='first')]

# %%
# 597078
df_undupped = df_geo.drop_duplicates(subset=['voterid'], keep='first')
df_undupped
# Out:
#         voterid                                         address_in  \
# 559   100002687  7044 Deer Lodge Cir APT 110, Jacksonville, FL,...
# 95    100005608          6925 Cartier CIR, Jacksonville, FL, 32208
# 375   100008211  1401 Riverplace Blvd 2309, Jacksonville, FL, 3...
# 441   100008843         2305 La Mesa Dr E, Jacksonville, FL, 32217
# 380   100012958  10061 Sweetwater Pkwy APT 239, Jacksonville, F...
# ...         ...                                                ...
# 114   132789129             3614 Effee St, Jacksonville, FL, 32209
# 67    132789169             5226 Polan Ln, Jacksonville, FL, 32209
# 24    132789187          2332 Mindanao Dr, Jacksonville, FL, 32246
# 432   132789210           4535 120Th St 8, Jacksonville, FL, 32244
# 1432  132789426         8346 Pineverde Ln, Jacksonville, FL, 32244
#
#      match_indicator match_type  \
# 559            Match  Non_Exact
# 95             Match      Exact
# 375            Match  Non_Exact
# 441            Match  Non_Exact
# 380            Match      Exact
# ...              ...        ...
# 114            Match      Exact
# 67             Match      Exact
# 24             Match      Exact
# 432            Match  Non_Exact
# 1432           Match      Exact
#
#                                          address_out  \
# 559      7044 DEERLODGE CIR, JACKSONVILLE, FL, 32256
# 95         6925 CARTIER CIR, JACKSONVILLE, FL, 32208
# 375    1401 RIVERPLACE BLVD, JACKSONVILLE, FL, 32207
# 441         2305 LA MESA DR, JACKSONVILLE, FL, 32217
# 380   10061 SWEETWATER PKWY, JACKSONVILLE, FL, 32256
# ...                                              ...
# 114           3614 EFFEE ST, JACKSONVILLE, FL, 32209
# 67            5226 POLAN LN, JACKSONVILLE, FL, 32209
# 24         2332 MINDANAO DR, JACKSONVILLE, FL, 32246
# 432           4535 120TH ST, JACKSONVILLE, FL, 32244
# 1432      8346 PINEVERDE LN, JACKSONVILLE, FL, 32244
#
#                                    long_lat tiger_edge street_side fips_state  \
# 559   -81.59145747292257,30.244896884401214  628032509           R         12
# 95      -81.7057683536849,30.39448921709453   83891528           R         12
# 375   -81.65632528432121,30.318594816974723  639971428           L         12
# 441   -81.63521984804595,30.252000692785202   83916805           R         12
# 380   -81.50636926182125,30.219390011992516  650105568           L         12
# ...                                     ...        ...         ...        ...
# 114    -81.68961842825928,30.36020125138515   83893737           L         12
# 67     -81.70664572654061,30.36692697597664   83891975           L         12
# 24     -81.51870493941993,30.30774686474382   83941831           L         12
# 432    -81.6999902517232,30.232380908053415  605436429           R         12
# 1432  -81.72278883281723,30.198591719406352  650065178           L         12
#
#      fips_county census_tract census_block   geocoder placeid            geoid
# 559          031       016605         2011  US Census          120310166052011
# 95           031       011300         2010  US Census          120310113002010
# 375          031       000800         2001  US Census          120310008002001
# 441          031       016500         4021  US Census          120310165004021
# 380          031       014424         3010  US Census          120310144243010
# ...          ...          ...          ...        ...     ...              ...
# 114          031       002801         2024  US Census          120310028012024
# 67           031       011600         1029  US Census          120310116001029
# 24           031       014338         2001  US Census          120310143382001
# 432          031       013301         1015  US Census          120310133011015
# 1432         031       013302         1002  US Census          120310133021002
#
# [597078 rows x 15 columns]

# %%
# 654778 x 15
df_matched = df_geocoded[df_geocoded['match_indicator']=='Match']
print(f"Matched row count:({len(df_matched)})")

df_matched = df_undupped[df_undupped['match_indicator']=='Match']
print(f"Matched UnDupped row count:({len(df_matched)})")

df_matched
# Out:
# Matched row count:(654778)
# Matched UnDupped row count:(597078)
#         voterid                                         address_in  \
# 559   100002687  7044 Deer Lodge Cir APT 110, Jacksonville, FL,...
# 95    100005608          6925 Cartier CIR, Jacksonville, FL, 32208
# 375   100008211  1401 Riverplace Blvd 2309, Jacksonville, FL, 3...
# 441   100008843         2305 La Mesa Dr E, Jacksonville, FL, 32217
# 380   100012958  10061 Sweetwater Pkwy APT 239, Jacksonville, F...
# ...         ...                                                ...
# 114   132789129             3614 Effee St, Jacksonville, FL, 32209
# 67    132789169             5226 Polan Ln, Jacksonville, FL, 32209
# 24    132789187          2332 Mindanao Dr, Jacksonville, FL, 32246
# 432   132789210           4535 120Th St 8, Jacksonville, FL, 32244
# 1432  132789426         8346 Pineverde Ln, Jacksonville, FL, 32244
#
#      match_indicator match_type  \
# 559            Match  Non_Exact
# 95             Match      Exact
# 375            Match  Non_Exact
# 441            Match  Non_Exact
# 380            Match      Exact
# ...              ...        ...
# 114            Match      Exact
# 67             Match      Exact
# 24             Match      Exact
# 432            Match  Non_Exact
# 1432           Match      Exact
#
#                                          address_out  \
# 559      7044 DEERLODGE CIR, JACKSONVILLE, FL, 32256
# 95         6925 CARTIER CIR, JACKSONVILLE, FL, 32208
# 375    1401 RIVERPLACE BLVD, JACKSONVILLE, FL, 32207
# 441         2305 LA MESA DR, JACKSONVILLE, FL, 32217
# 380   10061 SWEETWATER PKWY, JACKSONVILLE, FL, 32256
# ...                                              ...
# 114           3614 EFFEE ST, JACKSONVILLE, FL, 32209
# 67            5226 POLAN LN, JACKSONVILLE, FL, 32209
# 24         2332 MINDANAO DR, JACKSONVILLE, FL, 32246
# 432           4535 120TH ST, JACKSONVILLE, FL, 32244
# 1432      8346 PINEVERDE LN, JACKSONVILLE, FL, 32244
#
#                                    long_lat tiger_edge street_side fips_state  \
# 559   -81.59145747292257,30.244896884401214  628032509           R         12
# 95      -81.7057683536849,30.39448921709453   83891528           R         12
# 375   -81.65632528432121,30.318594816974723  639971428           L         12
# 441   -81.63521984804595,30.252000692785202   83916805           R         12
# 380   -81.50636926182125,30.219390011992516  650105568           L         12
# ...                                     ...        ...         ...        ...
# 114    -81.68961842825928,30.36020125138515   83893737           L         12
# 67     -81.70664572654061,30.36692697597664   83891975           L         12
# 24     -81.51870493941993,30.30774686474382   83941831           L         12
# 432    -81.6999902517232,30.232380908053415  605436429           R         12
# 1432  -81.72278883281723,30.198591719406352  650065178           L         12
#
#      fips_county census_tract census_block   geocoder placeid            geoid
# 559          031       016605         2011  US Census          120310166052011
# 95           031       011300         2010  US Census          120310113002010
# 375          031       000800         2001  US Census          120310008002001
# 441          031       016500         4021  US Census          120310165004021
# 380          031       014424         3010  US Census          120310144243010
# ...          ...          ...          ...        ...     ...              ...
# 114          031       002801         2024  US Census          120310028012024
# 67           031       011600         1029  US Census          120310116001029
# 24           031       014338         2001  US Census          120310143382001
# 432          031       013301         1015  US Census          120310133011015
# 1432         031       013302         1002  US Census          120310133021002
#
# [597078 rows x 15 columns]

# %% [markdown]
# # Save US Census batch geocoded records to table
# **NOTE:** this drops and recreates the table, beware!

# %%
host = 'localhost'
port = 5437
db = 'geocoder'
engine = create_engine(f'postgresql://sean:pass1234@{host}:{port}/{db}')

# %%
table = 'geolocations'
df_matched.head(0).to_sql(table, engine, if_exists='replace', index=True)
# Out:
# 0

# %%
conn = engine.raw_connection()
cur = conn.cursor()
output = io.StringIO()
df_matched.to_csv(output, sep='\t', header=False, index=True)
output.seek(0)
contents = output.getvalue()
cur.copy_from(output, table, null="")  # null values become ''
conn.commit()
cur.close()
conn.close()

# %% [markdown]
# # General sanity checking
# numbers add up??

# %%
# 106440 x 15
df_unmatched = df_geocoded[df_geocoded['match_indicator']!='Match']
outfile = f"{path}/unmatched-census-geocoded.csv"
print(f"Unmatched row count:({len(df_unmatched)}) -- writing to:({outfile}")
df_unmatched.to_csv(outfile)
df_unmatched
# Out:
# Unmatched row count:(106440) -- writing to:(/opt/data/GIS-Census/florida/geocoding/unmatched-census-geocoded.csv
#        voterid                                      address_in  \
# 22   103804235         11148 Windhaven Dr S, Oscoda, FL, 48750
# 24   118682821         3259 Brachenbury Ln, AUGUSTA, FL, 30909
# 30   117091742   11216 Ft Caroline Rd, Jacksonville, FL, 32225
# 31   103431942  1960 Holly Oaks Ravine Dr, Callahan, FL, 32011
# 33   104097093      3941 High Pine Rd, Jacksonville, FL, 32225
# ..         ...                                             ...
# 919  103283451   14073 La Launa Cir N, Jacksonville, FL, 32225
# 934  128405388  13919 Sugar Pine Ct, Virginia Beach, FL, 23455
# 942  124001212            1760 Chandelier Cir W, FPO, FL, 9834
# 973  127921986   13621 Mt Pleasant Rd, Jacksonville, FL, 32225
# 995  115524116   14151 Mt Pleasant Rd, Jacksonville, FL, 32225
#
#     match_indicator match_type address_out long_lat tiger_edge street_side  \
# 22         No_Match        NaN         NaN      NaN        NaN         NaN
# 24         No_Match        NaN         NaN      NaN        NaN         NaN
# 30              Tie        NaN         NaN      NaN        NaN         NaN
# 31         No_Match        NaN         NaN      NaN        NaN         NaN
# 33         No_Match        NaN         NaN      NaN        NaN         NaN
# ..              ...        ...         ...      ...        ...         ...
# 919        No_Match        NaN         NaN      NaN        NaN         NaN
# 934        No_Match        NaN         NaN      NaN        NaN         NaN
# 942        No_Match        NaN         NaN      NaN        NaN         NaN
# 973             Tie        NaN         NaN      NaN        NaN         NaN
# 995             Tie        NaN         NaN      NaN        NaN         NaN
#
#     fips_state fips_county census_tract census_block   geocoder placeid geoid
# 22         NaN         NaN          NaN          NaN  US Census           NaN
# 24         NaN         NaN          NaN          NaN  US Census           NaN
# 30         NaN         NaN          NaN          NaN  US Census           NaN
# 31         NaN         NaN          NaN          NaN  US Census           NaN
# 33         NaN         NaN          NaN          NaN  US Census           NaN
# ..         ...         ...          ...          ...        ...     ...   ...
# 919        NaN         NaN          NaN          NaN  US Census           NaN
# 934        NaN         NaN          NaN          NaN  US Census           NaN
# 942        NaN         NaN          NaN          NaN  US Census           NaN
# 973        NaN         NaN          NaN          NaN  US Census           NaN
# 995        NaN         NaN          NaN          NaN  US Census           NaN
#
# [106440 rows x 15 columns]
