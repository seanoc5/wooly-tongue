# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pinecone-io/examples/blob/master/learn/search/semantic-search/ner-search/ner-powered-search.ipynb) [![Open nbviewer](https://raw.githubusercontent.com/pinecone-io/examples/master/assets/nbviewer-shield.svg)](https://nbviewer.org/github/pinecone-io/examples/blob/master/learn/search/semantic-search/ner-search/ner-powered-search.ipynb)

# %% [markdown]
# # NER Powered Semantic Search
#
# **NOT WORKING**:
#
# ValueError: The argument order for `query()` has changed; please use keyword arguments instead of positional arguments. Example: index.query(vector=[0.1, 0.2, 0.3], top_k=10, namespace='my_namespace')

# %% [markdown]
# This notebook shows how to use Named Entity Recognition (NER) for hybrid metadata + vector search with Pinecone. We will:
#
# 1. Extract named entities from text.
# 2. Store them in a Pinecone index as metadata (alongside respective text vectors).
# 3. We extract named entities from incoming queries and use them to filter and search only through records containing these named entities.
#
# This is particularly helpful if you want to restrict the search score to records that contain information about the named entities that are also found within the query.
#
# Let's get started.

# %% [markdown]
# # Install Dependencies

# %%
#!pip install sentence_transformers pinecone-client==3.1.0 datasets -qU
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
import os
from pathlib import Path
from getpass import getpass
from pinecone import Pinecone

pak = "PINECONE_API_KEY"
if pak in os.environ:
    print("Found PINECONE_API_KEY in os.environ, no need to prompt")
else: 
    api_key = getpass("Enter PINECONE API key:")
    os.environ["PINECONE_API_KEY"] = api_key
    
# initialize connection to pinecone (get API key at app.pinecone.io)
# api_key = os.environ.get('PINECONE_API_KEY') or 'PINECONE_API_KEY'
# Out:
# /home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/pinecone/index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 from pathlib import Path
#       3 from getpass import getpass
# ----> 4 from pinecone import Pinecone
#       6 pak = "PINECONE_API_KEY"
#       7 if pak in os.environ:
#
# ImportError: cannot import name 'Pinecone' from 'pinecone' (/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/pinecone/__init__.py)

# %%
# configure client
pc = Pinecone(api_key=api_key)
idxs = pc.list_indexes
print(idxs)
# Out:
# <bound method Pinecone.list_indexes of <pinecone.control.pinecone.Pinecone object at 0x7f495c3cdfc0>>

# %% [markdown]
# # Load and Prepare Dataset

# %% [markdown]
# We use a dataset containing ~190K articles scraped from Medium. We select 50K articles from the dataset as indexing all the articles may take some time. This dataset can be loaded from the HuggingFace dataset hub as follows:

# %%
from datasets import load_dataset

# load the dataset and convert to pandas dataframe
df = load_dataset(
    "fabiochiu/medium-articles",
    data_files="medium_articles.csv",
    split="train"
).to_pandas()

# %%
# drop empty rows and select 20k articles
df = df.dropna().sample(20000, random_state=32)
df.head()
# Out:
#                                                     title  \
# 4172                         How the Data Stole Christmas
# 174868  Automating Light Switch using the ESP32 Board ...
# 100171    Keep Going Quotes Sayings for When Hope is Lost
# 141757     When Will the Smoke Clear From Bay Area Skies?
# 183489       The ABC’s of Sustainability… easy as 1, 2, 3
#
#                                                      text  \
# 4172    by Anonymous\n\nThe door sprung open and our t...
# 174868  A story about how I escaped the boring task th...
# 100171  It’s a very thrilling thing to achieve a goal....
# 141757  Bay Area cities are contending with some of th...
# 183489  By Julia DiPrete\n\n(according to the Jackson ...
#
#                                                       url  \
# 4172    https://medium.com/data-ops/how-the-data-stole...
# 174868  https://python.plainenglish.io/automating-ligh...
# 100171  https://medium.com/@yourselfquotes/keep-going-...
# 141757  https://thebolditalic.com/when-will-the-smoke-...
# 183489  https://medium.com/sipwines/the-abcs-of-sustai...
#
#                     authors                         timestamp  \
# 4172                     []  2019-12-24 13:22:33.143000+00:00
# 174868    ['Tomas Rasymas']  2021-09-14 07:20:52.342000+00:00
# 100171  ['Yourself Quotes']  2021-01-05 12:13:04.018000+00:00
# 141757    ['Matt Charnock']  2020-09-15 22:38:33.924000+00:00
# 183489        ['Sip Wines']  2021-03-02 23:39:49.948000+00:00
#
#                                                      tags
# 4172    ['Data Science', 'Big Data', 'Dataops', 'Analy...
# 174868  ['Programming', 'Python', 'Software Developmen...
# 100171                                         ['Quotes']
# 141757  ['Bay Area', 'San Francisco', 'California', 'W...
# 183489         ['Wine Tasting', 'Sustainability', 'Wine']

# %% [markdown]
# We will use the article title and its text for generating embeddings. For that, we join the article title and the first 1000 characters from the article text.

# %%
# select first 1000 characters
df["text"] = df["text"].str[:1000]
# join article title and the text
df["title_text"] = df["title"] + ". " + df["text"]

# %% [markdown]
# # Initialize NER Model

# %% [markdown]
# To extract named entities, we will use a NER model finetuned on a BERT-base model. The model can be loaded from the HuggingFace model hub as follows:

# %%
import torch

# set device to GPU if available
cuda_avail =  torch.cuda.is_available()
print(f"Cuda? {cuda_avail}")
device = torch.cuda.current_device() if torch.cuda.is_available() else None
print(f"Device: {device}")
# Out:
# Cuda? True
# Device: 0

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

model_id = "dslim/bert-base-NER"

# load the tokenizer from huggingface
tokenizer = AutoTokenizer.from_pretrained(
    model_id
)
# load the NER model from huggingface
model = AutoModelForTokenClassification.from_pretrained(
    model_id
)
# load the tokenizer and model into a NER pipeline
nlp = pipeline(
    "ner",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="max",
    device=device
)
# Out:
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[38], line 15
#      11 model = AutoModelForTokenClassification.from_pretrained(
#      12     model_id
#      13 )
#      14 # load the tokenizer and model into a NER pipeline
# ---> 15 nlp = pipeline(
#      16     "ner",
#      17     model=model,
#      18     tokenizer=tokenizer,
#      19     aggregation_strategy="max",
#      20     device=device
#      21 )
#
# File ~/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/transformers/pipelines/__init__.py:1107, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1104 if device is not None:
#    1105     kwargs["device"] = device
# -> 1107 return pipeline_class(model=model, framework=framework, task=task, **kwargs)
#
# File ~/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:135, in TokenClassificationPipeline.__init__(self, args_parser, *args, **kwargs)
#     134 def __init__(self, args_parser=TokenClassificationArgumentHandler(), *args, **kwargs):
# --> 135     super().__init__(*args, **kwargs)
#     136     self.check_model_type(
#     137         TF_MODEL_FOR_TOKEN_CLASSIFICATION_MAPPING_NAMES
#     138         if self.framework == "tf"
#     139         else MODEL_FOR_TOKEN_CLASSIFICATION_MAPPING_NAMES
#     140     )
#     142     self._basic_tokenizer = BasicTokenizer(do_lower_case=False)
#
# File ~/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/transformers/pipelines/base.py:874, in Pipeline.__init__(self, model, tokenizer, feature_extractor, image_processor, modelcard, framework, task, args_parser, device, torch_dtype, binary_output, **kwargs)
#     867 # We shouldn't call `model.to()` for models loaded with accelerate
#     868 if (
#     869     self.framework == "pt"
#     870     and self.device is not None
#     871     and not (isinstance(self.device, int) and self.device < 0)
#     872     and hf_device_map is None
#     873 ):
# --> 874     self.model.to(self.device)
#     876 # Update config and generation_config with task specific parameters
#     877 task_specific_params = self.model.config.task_specific_params
#
# File ~/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/transformers/modeling_utils.py:2576, in PreTrainedModel.to(self, *args, **kwargs)
#    2571     if dtype_present_in_args:
#    2572         raise ValueError(
#    2573             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    2574             " `dtype` by passing the correct `torch_dtype` argument."
#    2575         )
# -> 2576 return super().to(*args, **kwargs)
#
# File ~/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1152, in Module.to(self, *args, **kwargs)
#    1148         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1149                     non_blocking, memory_format=convert_to_format)
#    1150     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1152 return self._apply(convert)
#
# File ~/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/torch/nn/modules/module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File ~/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/torch/nn/modules/module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File ~/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/torch/nn/modules/module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File ~/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/torch/nn/modules/module.py:825, in Module._apply(self, fn, recurse)
#     821 # Tensors stored in modules are graph leaves, and we don't want to
#     822 # track autograd history of `param_applied`, so we have to use
#     823 # `with torch.no_grad():`
#     824 with torch.no_grad():
# --> 825     param_applied = fn(param)
#     826 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     827 if should_use_set_data:
#
# File ~/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1150, in Module.to.<locals>.convert(t)
#    1147 if convert_to_format is not None and t.dim() in (4, 5):
#    1148     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1149                 non_blocking, memory_format=convert_to_format)
# -> 1150 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# RuntimeError: CUDA error: unknown error
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
text = "London is the capital of England and the United Kingdom"
# use the NER pipeline to extract named entities from the text
nlp(text)
# Out:
# [{'entity_group': 'LOC',
#   'score': 0.9996493,
#   'word': 'London',
#   'start': 0,
#   'end': 6},
#  {'entity_group': 'LOC',
#   'score': 0.9997588,
#   'word': 'England',
#   'start': 25,
#   'end': 32},
#  {'entity_group': 'LOC',
#   'score': 0.9993923,
#   'word': 'United Kingdom',
#   'start': 41,
#   'end': 55}]

# %% [markdown]
# Our NER pipeline is working as expected and accurately extracting entities from the text.

# %% [markdown]
# # Initialize Retriever

# %% [markdown]
# A retriever model is used to embed passages (article title + first 1000 characters) and queries. It creates embeddings such that queries and passages with similar meanings are close in the vector space. We will use a sentence-transformer model as our retriever. The model can be loaded as follows:

# %%
from sentence_transformers import SentenceTransformer

# load the model from huggingface
retriever = SentenceTransformer(
    'flax-sentence-embeddings/all_datasets_v3_mpnet-base',
    device=device
)
retriever
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 128, 'do_lower_case': False}) with Transformer model: MPNetModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %% [markdown]
# # Initialize Pinecone Index

# %% [markdown]
# Now we need to initialize our Pinecone index. The Pinecone index stores vector representations of our passages which we can retrieve using another vector (the query vector). We first need to initialize our connection to Pinecone. For this, we need a free [API key](https://app.pinecone.io/); you can find your environment in the [Pinecone console](https://app.pinecone.io) under **API Keys**. We initialize the connection like so:

# %% [markdown]
# Now we setup our index specification, this allows us to define the cloud provider and region where we want to deploy our index. You can find a list of all [available providers and regions here](https://docs.pinecone.io/docs/projects).

# %%
from pinecone import ServerlessSpec

cloud = os.environ.get('PINECONE_CLOUD') or 'aws'
region = os.environ.get('PINECONE_REGION') or 'us-east-1'

spec = ServerlessSpec(cloud=cloud, region=region)

# %% [markdown]
# Now we can create our vector index. We will name it `ner-search` (feel free to chose any name you prefer). We specify the metric type as `cosine` and dimension as `768` as these are the vector space and dimensionality of the vectors output by the retriever model.

# %%
index_name = "ner-search"

# %%
import time

# check if index already exists (it shouldn't if this is first time)
if index_name not in pc.list_indexes().names():
    # if does not exist, create index
    print(f"Create index: {index_name}")
    pc.create_index(
        index_name,
        dimension=768,
        metric='cosine',
        spec=spec
    )
    # wait for index to be initialized
    while not pc.describe_index(index_name).status['ready']:
        print(f"\tsleeing, waiting for {inindex_name} to be ready")
        time.sleep(1)
# Out:
# Create index: ner-search

# %%
# connect to index
index = pc.Index(index_name)
# view index stats
index.describe_index_stats()
# Out:
# {'dimension': 768,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %% [markdown]
# # Generate Embeddings and Upsert

# %% [markdown]
# We generate embeddings for the `title_text` column we created earlier. Alongside the embeddings, we also include the named entities in the index as metadata. Later we will apply a filter based on these named entities when executing queries.
#
# Let's first write a helper function to extract named entities from a batch of text.

# %%
def extract_named_entities(text_batch):
    # extract named entities using the NER pipeline
    extracted_batch = nlp(text_batch)
    entities = []
    # loop through the results and only select the entity names
    for text in extracted_batch:
        ne = [entity["word"] for entity in text]
        entities.append(ne)
    return entities

# %% [markdown]
# Now we create the embeddings. We do this in batches of `64` to avoid overwhelming machine resources or API request limits.

# %%
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# we will use batches of 64
batch_size = 64

for i in tqdm(range(0, len(df), batch_size)):
    # find end of batch
    i_end = min(i+batch_size, len(df))
    # extract batch
    batch = df.iloc[i:i_end].copy()
    # generate embeddings for batch
    emb = retriever.encode(batch["title_text"].tolist()).tolist()
    # extract named entities from the batch
    entities = extract_named_entities(batch["title_text"].tolist())
    # remove duplicate entities from each record
    batch["named_entities"] = [list(set(entity)) for entity in entities]
    batch = batch.drop('title_text', axis=1)
    # get metadata
    meta = batch.to_dict(orient="records")
    # create unique IDs
    ids = [f"{idx}" for idx in range(i, i_end)]
    # add all to upsert list
    to_upsert = list(zip(ids, emb, meta))
    # upsert/insert these records to pinecone
    _ = index.upsert(vectors=to_upsert)

# check that we have all vectors in index
index.describe_index_stats()
# Out:
#   0%|          | 0/313 [00:00<?, ?it/s]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/logging/__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/logging/__init__.py", line 942, in format
#     return fmt.format(record)
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/asyncio/base_events.py", line 595, in run_forever
#     self._run_once()
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/asyncio/base_events.py", line 1881, in _run_once
#     handle._run()
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_799877/2412679860.py", line 16, in <module>
#     entities = extract_named_entities(batch["title_text"].tolist())
#   File "/tmp/ipykernel_799877/24236003.py", line 3, in extract_named_entities
#     extracted_batch = nlp(text_batch)
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/transformers/pipelines/token_classification.py", line 248, in __call__
#     return super().__call__(inputs, **kwargs)
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/transformers/pipelines/base.py", line 1167, in __call__
#     logger.warning_once(
#   File "/home/sean/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/transformers/utils/logging.py", line 329, in warning_once
#     self.warning(*args, **kwargs)
# Message: 'You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset'
# Arguments: (<class 'UserWarning'>,)
# {'dimension': 768,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 19968}},
#  'total_vector_count': 19968}

# %% [markdown]
# Now we have indexed the articles and relevant metadata. We can move on to querying.

# %% [markdown]
# # Querying

# %% [markdown]
# First, we will write a helper function to handle the queries.

# %%
from pprint import pprint

def search_pinecone(query):
    # extract named entities from the query
    ne = extract_named_entities([query])[0]
    # create embeddings for the query
    xq = retriever.encode(query).tolist()
    # query the pinecone index while applying named entity filter
    xc = index.query(xq, top_k=10, include_metadata=True, filter={"named_entities": {"$in": ne}})
    # extract article titles from the search result
    r = [x["metadata"]["title"] for x in xc["matches"]]
    return pprint({"Extracted Named Entities": ne, "Result": r})

# %% [markdown]
# Now try a query.

# %%
query = "What are the best places to visit in Greece?"
search_pinecone(query)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 query = "What are the best places to visit in Greece?"
# ----> 2 search_pinecone(query)
#
# Cell In[29], line 9, in search_pinecone(query)
#       7 xq = retriever.encode(query).tolist()
#       8 # query the pinecone index while applying named entity filter
# ----> 9 xc = index.query(xq, top_k=10, include_metadata=True, filter={"named_entities": {"$in": ne}})
#      10 # extract article titles from the search result
#      11 r = [x["metadata"]["title"] for x in xc["matches"]]
#
# File ~/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/pinecone/utils/error_handling.py:10, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#       7 @wraps(func)
#       8 def inner_func(*args, **kwargs):
#       9     try:
# ---> 10         return func(*args, **kwargs)
#      11     except MaxRetryError as e:
#      12         if isinstance(e.reason, ProtocolError):
#
# File ~/miniforge3/envs/pinecode-haystack-env/lib/python3.10/site-packages/pinecone/data/index.py:378, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     336 """
#     337 The Query operation searches a namespace, using a query vector.
#     338 It retrieves the ids of the most similar items in a namespace, along with their similarity scores.
#    (...)
#     374          and namespace name.
#     375 """
#     377 if len(args) > 0:
# --> 378     raise ValueError("The argument order for `query()` has changed; please use keyword arguments instead of positional arguments. Example: index.query(vector=[0.1, 0.2, 0.3], top_k=10, namespace='my_namespace')")
#     380 if vector is not None and id is not None:
#     381     raise ValueError("Cannot specify both `id` and `vector`")
#
# ValueError: The argument order for `query()` has changed; please use keyword arguments instead of positional arguments. Example: index.query(vector=[0.1, 0.2, 0.3], top_k=10, namespace='my_namespace')

# %%
query = "What are the best places to visit in London?"
search_pinecone(query)

# %%
query = "Why does SpaceX want to build a city on Mars?"
search_pinecone(query)

# %% [markdown]
# These all look like great results, making the most of Pinecone's advanced vector search capabilities while limiting search scope to relevant records only with a named entity filter.

# %%
pc.delete_index(index_name)
